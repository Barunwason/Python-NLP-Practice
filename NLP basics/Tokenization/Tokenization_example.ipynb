# %%
corpus="""Hello, My name is Barun Wason.
I am computer science student currently pursuing my master in computer application.
And i am learning machine learning and deep learning for Natural language processing.
"""

# %%
print(corpus)
# Out:
# Hello, My name is Barun Wason.
# I am computer science student currently pursuing my master in computer application.
# And i am learning machine learning and deep learning for Natural language processing.

# %%
pip install nltk
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/barunwason/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
list1=sent_tokenize(corpus)
list1
# Out:
# ['Hello, My name is Barun Wason.',
#  'I am computer science student currently pursuing my master in computer application.',
#  'And i am learning machine learning and deep learning for Natural language processing.']

# %%
from nltk.tokenize import word_tokenize

# %%
for i in list1: print(word_tokenize(i))
# Out:
# ['Hello', ',', 'My', 'name', 'is', 'Barun', 'Wason', '.']
# ['I', 'am', 'computer', 'science', 'student', 'currently', 'pursuing', 'my', 'master', 'in', 'computer', 'application', '.']
# ['And', 'i', 'am', 'learning', 'machine', 'learning', 'and', 'deep', 'learning', 'for', 'Natural', 'language', 'processing', '.']

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'My',
#  'name',
#  'is',
#  'Barun',
#  'Wason',
#  '.',
#  'I',
#  'am',
#  'computer',
#  'science',
#  'student',
#  'currently',
#  'pursuing',
#  'my',
#  'master',
#  'in',
#  'computer',
#  'application',
#  '.',
#  'And',
#  'i',
#  'am',
#  'learning',
#  'machine',
#  'learning',
#  'and',
#  'deep',
#  'learning',
#  'for',
#  'Natural',
#  'language',
#  'processing',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer=TreebankWordTokenizer()

# %%
word_tokens=tokenizer.tokenize(corpus)
word_tokens
# Out:
# ['Hello',
#  ',',
#  'My',
#  'name',
#  'is',
#  'Barun',
#  'Wason.',
#  'I',
#  'am',
#  'computer',
#  'science',
#  'student',
#  'currently',
#  'pursuing',
#  'my',
#  'master',
#  'in',
#  'computer',
#  'application.',
#  'And',
#  'i',
#  'am',
#  'learning',
#  'machine',
#  'learning',
#  'and',
#  'deep',
#  'learning',
#  'for',
#  'Natural',
#  'language',
#  'processing',
#  '.']

# %%
from nltk.tokenize import TreebankWordDetokenizer
detokenizer = TreebankWordDetokenizer()
detokenizer.tokenize(word_tokens)
# Out:
# 'Hello, My name is Barun Wason. I am computer science student currently pursuing my master in computer application. And i am learning machine learning and deep learning for Natural language processing.'
