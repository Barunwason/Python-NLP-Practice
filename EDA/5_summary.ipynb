# %%
import numpy as np
data=[23,46,32,78,76,89,57,77,18,20,79,99,97,69,68,45]
minimum,Q1,median,Q3,maximum=np.quantile(data,[0,0.25,0.50,0.75,1])
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(18.0),
#  np.float64(41.75),
#  np.float64(68.5),
#  np.float64(78.25),
#  np.float64(99.0))

# %%
IQR=Q3-Q1
lower_fence=Q1-1.5*(IQR)
higher_fence=Q3+1.5*(IQR)
print(lower_fence,higher_fence)
# Out:
# -13.0 133.0

# %%
import seaborn as sns
sns.boxplot(data)
# Out:
# <Axes: >
